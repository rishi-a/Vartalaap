# %%
import pandas as pd
import numpy as np
import pickle

# %%
data = pd.read_pickle('clean_data.pkl')
data
# Out:
#                                                       0
# 0           familiar negat effect pollut know damag eye
# 1     rebuild neighbourhood layout act solar calenda...
# 2     filter protect brain pollut learn filter abil ...
# 3                  shortterm effect pollut bloodpressur
# 4     background cool paper europ general germani pa...
# ...                                                 ...
# 2022  octob issu look pollut effect brain think orig...
# 2023  intern preval chemic sensit copreval asthma au...
# 2024  cite report show mortal effect youll know poll...
# 2025  diolch fawr iawn mcgarri ddod trafod llygredd ...
# 2026   boost immun fight effect pollut onion help write
#
# [2027 rows x 1 columns]

# %%
# Create quick lambda functions to find the polarity and subjectivity of each routine
# Terminal / Anaconda Navigator: conda install -c conda-forge textblob
from textblob import TextBlob

pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

data['polarity'] = data[0].apply(pol)
data['subjectivity'] = data[0].apply(sub)
data
# Out:
#                                                       0  polarity  \
# 0           familiar negat effect pollut know damag eye  0.375000
# 1     rebuild neighbourhood layout act solar calenda...  0.200000
# 2     filter protect brain pollut learn filter abil ...  0.000000
# 3                  shortterm effect pollut bloodpressur  0.000000
# 4     background cool paper europ general germani pa... -0.033333
# ...                                                 ...       ...
# 2022  octob issu look pollut effect brain think orig...  0.000000
# 2023  intern preval chemic sensit copreval asthma au...  0.000000
# 2024  cite report show mortal effect youll know poll...  0.266667
# 2025  diolch fawr iawn mcgarri ddod trafod llygredd ...  0.000000
# 2026   boost immun fight effect pollut onion help write  0.000000
#
#       subjectivity
# 0         0.500000
# 1         0.350000
# 2         0.000000
# 3         0.000000
# 4         0.537500
# ...            ...
# 2022      0.000000
# 2023      0.000000
# 2024      0.416667
# 2025      0.000000
# 2026      0.000000
#
# [2027 rows x 3 columns]

# %%
data.to_csv('sentiment-tblob-result.csv')
